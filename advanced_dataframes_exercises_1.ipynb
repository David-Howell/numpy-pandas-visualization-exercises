# %% [markdown]
# # Exercises I
# #### Run python -m pip install pymysql from your terminal to install pymysql.
#
# ##### Create a notebook or python script named advanced_dataframes to do your work in for these exercises.

# %% [markdown]
# 1. Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)

# %% [markdown]
# 2. cd into your exercises folder for this module and run echo env.py >> .gitignore

# %% [markdown]
# 3. Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %% [markdown]
# 4. Use your function to obtain a connection to the employees database.

# %% [markdown]
# 5. Once you have successfully run a query:

# %% [markdown]
#    a. Intentionally make a typo in the database url. What kind of error message do you see?

# %% [markdown]
#    b. Intentionally make an error in your SQL query. What does the error message look like?

# %% [markdown]
# 6. Read the employees and titles tables into two separate DataFrames.

# %% [markdown]
# 7. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %% [markdown]
# 8. Display the summary statistics for each DataFrame.

# %% [markdown]
# 9. How many unique titles are in the titles DataFrame?

# %% [markdown]
# 10. What is the oldest date in the to_date column?

# %% [markdown]
# 11. What is the most recent date in the to_date column?

# %% [markdown]
# ## Exercises I
#
# Run `python -m pip install mysqlclient pymysql` from your terminal to install pymysql and the mysqlclient.
#
# Create a notebook or python script named `advanced_dataframes` to do your work in for these exercises.

# %% [markdown]
# 1. Create a function named `get_db_url`. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
# def get_db_url(schema):
#     import env
#     user = env.username
#     password = env.password
#     host = env.host
#     conn = f'mysql+pymysql://{user}:{password}@{host}/{schema}'
#     return conn

# %%
def get_db_url(db, env_file=os.path.exists('env.py')):
    '''
    returns a formatted string ready to utilize as a sql url connection
    
    args: db: a string literal representing a schema
    env_file: bool: checks to see if there is an env.py present in the cwd
    
    make sure that if you have an env file that you import it outside of the scope 
    of this function call, otherwise env.user wont mean anything ;)
    '''
    import os
    if env_file:
        user, password, host = (env.user, env.password, env.host)
        return f'mysql+pymysql://{user}:{password}@{host}/{db}'
    else:
        return 'yo you need some credentials to access a database usually and I dont want you to type them here.'

# %% [markdown]
# 2. Use your function to obtain a connection to the `employees` database.

# %%
import numpy as np
import pandas as pd

# %%
query = 'SELECT * FROM employees LIMIT 100'

# %%
df = pd.read_sql(query, get_db_url('employees'))

# %%
df
# Out:
#     emp_no  birth_date   first_name    last_name gender   hire_date
# 0    10001  1953-09-02       Georgi      Facello      M  1986-06-26
# 1    10002  1964-06-02      Bezalel       Simmel      F  1985-11-21
# 2    10003  1959-12-03        Parto      Bamford      M  1986-08-28
# 3    10004  1954-05-01    Chirstian      Koblick      M  1986-12-01
# 4    10005  1955-01-21      Kyoichi     Maliniak      M  1989-09-12
# ..     ...         ...          ...          ...    ...         ...
# 95   10096  1954-09-16       Jayson      Mandell      M  1990-01-14
# 96   10097  1952-02-27        Remzi  Waschkowski      M  1990-09-15
# 97   10098  1961-09-23  Sreekrishna    Servieres      F  1985-05-13
# 98   10099  1956-05-25       Valter      Sullins      F  1988-10-18
# 99   10100  1953-04-21     Hironobu    Haraldson      F  1987-09-21
#
# [100 rows x 6 columns]

# %% [markdown]
# 3. Once you have successfully run a query:
#
#     a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
ten_emp_no = pd.read_sql('SELECT emp_no FROM employees LIMIT 10', get_db_url('employeeees') )
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %% [markdown]
# ### OperationalError: The Connection Fairy didn't like me

# %% [markdown]
#     b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
ten_emp_no = pd.read_sql('SEECT emp_no FROM employees LIMIT 10', get_db_url('employees') )
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
# ...

# %% [markdown]
# #### ProgrammingError: 1064, You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version

# %%
ten_emp_no = pd.read_sql('SELECT emp_no FROM employees LIMIT 10', get_db_url('employees') )

# %%
ten_emp_no
# Out:
#    emp_no
# 0   10001
# 1   10002
# 2   10003
# 3   10004
# 4   10005
# 5   10006
# 6   10007
# 7   10008
# 8   10009
# 9   10010

# %% [markdown]
# 4. Read the `employees` and `titles` tables into two separate DataFrames.

# %%
employees = pd.read_sql('SELECT * FROM employees', get_db_url('employees'))

# %%
titles = pd.read_sql('SELECT * FROM titles', get_db_url('employees'))

# %% [markdown]
# 5. How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %% [markdown]
# 6. Display the summary statistics for each DataFrame.

# %%
employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
employees.to_csv('employees_employees.csv')

# %%
titles.to_csv('employees_titles.csv')

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %% [markdown]
# 7. How many unique titles are in the `titles` DataFrame?

# %%
titles.title.unique(), len(titles.title.unique())
# Out:
# (array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#         'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object),
#  7)

# %% [markdown]
# 8. What is the oldest date in the `to_date` column?

# %%
titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# 9. What is the most recent date in the `to_date` column?

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %%
titles['from_date'] = pd.to_datetime(titles['from_date'])

# %%
titles['to_date'].head()
# Out:
# 0    9999-01-01
# 1    9999-01-01
# 2    9999-01-01
# 3    1995-12-01
# 4    9999-01-01
# Name: to_date, dtype: object

# %%
import datetime as dt

# %%
help()
# Out:
# Welcome to Python 3.9's help utility!
#
# If this is your first time using Python, you should definitely check out
# the tutorial on the Internet at https://docs.python.org/3.9/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To quit this help utility and
# return to the interpreter, just type "quit".
#
# To get a list of available modules, keywords, symbols, or topics, type
# "modules", "keywords", "symbols", or "topics".  Each module also comes
# with a one-line summary of what it does; to list the modules whose name
# or summary contain a given string such as "spam", type "modules spam".
#
# help> dt
# No Python documentation found for 'dt'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# help> datetime
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# MODULE REFERENCE
# ...

# %%
titles['to_date'][titles['to_date']!=dt.date(9999,1,1,)].max()
# Out:
# datetime.date(2002, 8, 1)

# %%
titles['to_date'] = pd.to_datetime(titles['to_date'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'datetime.date'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ...

# %%
titles.to_date[titles.to_date < pd.to_datetime(['9999-01-01'])].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# ...

# %%
print(titles['to_date'][titles['to_date']!=dt.date(9999,1,1)].max())
# Out:
# 2002-08-01
