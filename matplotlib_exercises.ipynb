# %% [markdown]
# # Exercises
# Using the `repo setup directions`, setup a new local and remote repository named `numpy-pandas-visualization-exercises`. The local version of your repo should live inside of `~/codeup-data-science`. This repo should be named `numpy-pandas-visualization-exercises`
#
# Do your work for this exercise in a **jupyter notebook** named `matplotlib_exercises`.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 1. Use matplotlib to plot the following equation:
#
#       ### $y = x^2 − x +2$
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
x = [n for n in range(-30,31)]
y = [n**2 - n + 2 for n in range(-30,31)]

# %%
plt.figure(figsize=(12,6))
plt.plot(x,y, c='red')
plt.vlines(0, -50, 1000, color='black')
plt.hlines(0, -30, 30, color='black')
plt.xlim(-30,30)
plt.ylim(-30, 1000)
plt.annotate('The Origin',
            xy = (0,0),
            xytext = (4,200),
            rotation = 30,
            arrowprops={'facecolor': 'blue'})
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
#
# $y=√x$
#
# $y=x^3$
#
# $y=2^x$
#
# $y=1/(x+1)$
#
#
# You can use functions from the `math` module to help implement some of the equations above.

# %%
t1 = '$y=√x$'
t2 = '$y=x^3$'
t3 = '$y=2^x$'
t4 = '$y=1/(x+1)$'

# %%
import math

# %%
x1 = []
y1 = []
x2 = []
y2 = []
x3 = []
y3 = []
x4 = []
y4 = []

for x in range(1,201):
    x1 += [x]
    y1 += [math.sqrt(x)]
    

for x in range(-10,11):
    x2 += [x]
    y2 += [x**3]
    
for x in range(-10,11):
    x3 += [x]
    y3 += [2**x]
    
for x in range(-100,101):
    x /= 10
    if x == -1:
        continue
    x4 += [x]
    y4 += [1/(x+1)]

# %%
len(x4)
# Out:
# 200

# %%
len(y4)
# Out:
# 200

# %%
plt.figure(figsize=(12,6))

plt.plot(x1,y1)
plt.title(t1)
plt.hlines(0, -10, x1[-1], color='black')
plt.vlines(0, -1, y1[-1], color='black')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))

plt.plot(x2,y2)
plt.title(t2)
plt.hlines(0, -11, 11, color='black')
plt.vlines(0, -1010, 1010, color='black')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))

plt.plot(x3,y3)
plt.title(t3, fontsize=20)
plt.hlines(0, -10, 10, color='black')
plt.vlines(0, 0, 100, color='black')
plt.xlim(-5,10)
plt.ylim(0,100)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(12,6))

plt.plot(x4,y4)
plt.title(t4, fontsize=20)
plt.annotate('$x=-1$ divides by $0$ \nand is omited',
             fontsize=13,
            xy=(-1,0),
            xytext=(2.5,-5),
            arrowprops={'facecolor':'red'})
plt.xlim(-10,10)
plt.ylim(-10,10)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
plt.figure(figsize=(12,8))


plt.subplot(221)
plt.plot(x1,y1)
plt.title(t1)
plt.hlines(0, -10, x1[-1], color='black')
plt.vlines(0, -1, y1[-1], color='black')

plt.subplot(222)
plt.plot(x2,y2)
plt.title(t2)
plt.hlines(0, -11, 11, color='black')
plt.vlines(0, -1010, 1010, color='black')


plt.subplot(223)
plt.plot(x3,y3)
plt.title(t3, fontsize=20)
plt.hlines(0, -10, 10, color='black')
plt.vlines(0, 0, 100, color='black')
plt.xlim(-5,10)
plt.ylim(0,100)



plt.subplot(224)
plt.plot(x4,y4)
plt.title(t4)
plt.hlines(0, -10, 11, color='black')
plt.vlines(0, -10, 11, color='black')
plt.annotate('at $x=-1$ \n $y=\frac{1}{0}$ \nand is omited',
            xy=(-1,0),
            xytext=(-10, 5),
            arrowprops={'facecolor':'red'})

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize=(12,8))


# plt.subplot(221)
plt.plot(x1,y1, color = 'red', label = t1)
# plt.title(t1)
# plt.hlines(0, -10, x1[-1], color='black')
# plt.vlines(0, -1, y1[-1], color='black')

# plt.subplot(222)
plt.plot(x2,y2, color = 'blue', label = t2)
# plt.title(t2)
# plt.hlines(0, -11, 11, color='black')
# plt.vlines(0, -1010, 1010, color='black')


# plt.subplot(223)
plt.plot(x3,y3, color = 'green', label = t3)
# plt.title(t3)
# plt.hlines(0, -10, 10, color='black')
# plt.vlines(0, 0, 100, color='black')
# plt.xlim(-5,10)
# plt.ylim(0,100)


# plt.subplot(224)
plt.plot(x4,y4, color = 'orange', label = t4)
# plt.title(t4)
plt.annotate('at  $x=-1$\n     $y=1/0$ \nand as such \nis omited', fontsize=13,
            xy=(-1,0),
            xytext=(-8,10),
            arrowprops={'facecolor':'orange'})
plt.xlim(-10,21)
plt.ylim(-20,21)
plt.title(f'Graph of the following functions:\n{t1}  |  {t2}  |  {t3}  |  {t4}', fontsize=16)
plt.legend(loc=1, fontsize=13)
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 5. Make a new Jupyter notebook named big_o_notation.ipynb
#
# - Title your chart "Big O Notation"
# - Label your x axis "Elements"
# - Label your y axis "Operations"
# - Label your curves or make a legend for the curves
# - Use LaTex notation where possible
#
# Curves to graph
#
# $y=0n+1$ and label the curve "O(1)"
#
# $y=log(n)$ and label the curve "O(log n)"
#
# $y=n$ and label the curve "O(n)"
#
# $y=n∗log(n)$ and label it "O(n log n)"
#
# $y=n^2$ and label it "O(n^2)"
#
# $y=2^n$ and label it "O(2^n)"
#
# $y=n!$ and label it "O(n!)"
#
# $y=n^n$ and label it "O(n^n)"

# %% [markdown]
# 6. **Bonus:** Write the code necessary to write your name on a chart. Use box letters.

# %% [markdown]
# 7. **Bonus:** use curves for letters in your name that have curves in them.
